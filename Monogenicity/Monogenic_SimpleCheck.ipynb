# %% [markdown]
# <a href="https://colab.research.google.com/github/daphneplott/MonogenicFieldsOfCryptographicSize/blob/main/Monogenic_NotMonogenic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This file takes a given f(x) and given c, and calculates the discriminants of both f(x) and F(x), and the discriminants of the number fields of both.

# %%
R.<x> = QQ[]

f =

c =

F = x^ * f(1/x + c + x)

print(f.discriminant())
H.<v> = NumberField(f)
OH = H.ring_of_integers()
disc_f_field = OH.discriminant()
print(disc_f_field)

print(F.discriminant())
K.<u> = NumberField(F)
OK = K.ring_of_integers()
disc_F_field = OK.discriminant()
print(disc_F_field)
