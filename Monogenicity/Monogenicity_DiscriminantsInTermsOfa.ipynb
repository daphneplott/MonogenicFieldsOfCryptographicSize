# %% [markdown]
# <a href="https://colab.research.google.com/github/daphneplott/MonogenicFieldsOfCryptographicSize/blob/main/Monogenicity_DiscriminantsInTermsOfa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The first block of code calculates the roots of F(x), F^2(x) and F^3(x) when starting with some f(x) = x - a. It then calculates the discriminant of this F^3(x) according to the discriminant equals the product of the differences between roots.
#
# The next block of code just takes some f(x) = x - a, and calculates 5 iterations, and looks at the discriminants, in terms of generic a and c values.

# %%
import itertools
R.<a> = QQ[]

b1 = 1/2 * (a + sqrt(a^2 - 4))
b2 = 1/2 * (a - sqrt(a^2 - 4))

c1 = 1/2 * (b1 + sqrt(b1^2 -4))
c2 = 1/2 * (b1 - sqrt(b1^2 - 4))
c3 = 1/2 * (b2 + sqrt(b2^2 - 4))
c4 = 1/2 * (b2 - sqrt(b2^2 - 4))

di = []
for c in [c1,c2,c3,c4]:
    di.append(1/2 * (c + sqrt(c^2 - 4)))
    di.append(1/2 * (c - sqrt(c^2 - 4)))

combinations2 = itertools.combinations(di,2)
disc = 1
for combo in combinations2:
    disc = disc * (combo[0] - combo[1])^2

print(disc)
print(disc.expand())
print(disc.expand().factor())

# %%
R.<x, a,c > = QQ[]

f1 = x - a
f2 = R(f1(1/x + c + x, a,c)*x)
f3 = R(f2(1/x + c + x, a,c)*x^2)
f4 = R(f3(1/x + c + x, a,c)*x^4)
f5 = R(f4(1/x + c + x, a,c)*x^8)


print(factor(f1.discriminant(x)))
print()
print(factor(f2.discriminant(x)))
print()
print(factor(f3.discriminant(x)))
print()
print(factor(f4.discriminant(x)))
print()
print(factor(f5.discriminant(x)))
